# %%
#hide
import warnings
warnings.filterwarnings('ignore')

! [ -e /content ] && pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.8/719.8 kB 18.5 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.1/124.1 kB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 11.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.9/246.9 kB 14.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.5 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 10.1 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 2.3 MB/s eta 0:00:000:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 61.9 MB/s eta 0:00:00:00:0100:01
# ...

# %%
#hide
from fastbook import *
from IPython.display import display,HTML

# %% [markdown]
# # NLP Deep Dive: RNNs

# %% [markdown]
# ## Text Preprocessing

# %% [markdown]
# ### Tokenization

# %% [markdown]
# ### Word Tokenization with fastai

# %%
from fastai.text.all import *
path = untar_data(URLs.IMDB)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='144441344' class='' max='144440600' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [144441344/144440600 00:03&lt;00:00]
#     </div>

# %%
files = get_text_files(path, folders = ['train', 'test', 'unsup'])

# %%
# ?get_text_files
# Out:
# Signature: get_text_files(path, recurse=True, folders=None)
# Docstring: Get text files in `path` recursively, only in `folders`, if specified.
# File:      /usr/local/lib/python3.11/dist-packages/fastai/data/transforms.py
# Type:      function

# %%
txt = files[0].open().read(); txt[:75]
# Out:
# 'Jiang Xian uses the complex backstory of Ling Ling and Mao Daobing to study'

# %%
spacy = WordTokenizer()
toks = first(spacy([txt]))
print(coll_repr(toks, 30))
# Out:
# (#143) ['Jiang','Xian','uses','the','complex','backstory','of','Ling','Ling','and','Mao','Daobing','to','study','Mao',"'s",'"','cultural','revolution','"','(','1966','-','1976',')','at','the','village','level','.'...]

# %%
# ?coll_repr
# Out:
# Signature: coll_repr(c, max_n=20)
# Docstring: String repr of up to `max_n` items of (possibly lazy) collection `c`
# File:      /usr/local/lib/python3.11/dist-packages/fastcore/foundation.py
# Type:      function

# %%
first(spacy(['The U.S. dollar $1 is $1.00.']))
# Out:
# (#9) ['The','U.S.','dollar','$','1','is','$','1.00','.']

# %%
tkn = Tokenizer(spacy)
print(coll_repr(tkn(txt), 31))
# Out:
# (#158) ['xxbos','xxmaj','jiang','xxmaj','xian','uses','the','complex','backstory','of','xxmaj','ling','xxmaj','ling','and','xxmaj','mao','xxmaj','daobing','to','study','xxmaj','mao',"'s",'"','cultural','revolution','"','(','1966','-'...]

# %%
defaults.text_proc_rules
# Out:
# [<function fastai.text.core.fix_html(x)>,
#  <function fastai.text.core.replace_rep(t)>,
#  <function fastai.text.core.replace_wrep(t)>,
#  <function fastai.text.core.spec_add_spaces(t)>,
#  <function fastai.text.core.rm_useless_spaces(t)>,
#  <function fastai.text.core.replace_all_caps(t)>,
#  <function fastai.text.core.replace_maj(t)>,
#  <function fastai.text.core.lowercase(t, add_bos=True, add_eos=False)>]

# %%
coll_repr(tkn('&copy;   Fast.ai www.fast.ai/INDEX'), 31)
# Out:
# "(#11) ['xxbos','©','xxmaj','fast.ai','xxrep','3','w','.fast.ai','/','xxup','index']"

# %% [markdown]
# ### Subword Tokenization

# %%
txts = L(o.open().read() for o in files[:2000])

# %%
def subword(sz):
    sp = SubwordTokenizer(vocab_sz=sz)
    sp.setup(txts)
    return ' '.join(first(sp([txt]))[:40])

# %%
subword(1000)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# sentencepiece_trainer.cc(178) LOG(INFO) Running command: --input=tmp/texts.out --vocab_size=1000 --model_prefix=tmp/spm --character_coverage=0.99999 --model_type=unigram --unk_id=9 --pad_id=-1 --bos_id=-1 --eos_id=-1 --minloglevel=2 --user_defined_symbols=▁xxunk,▁xxpad,▁xxbos,▁xxeos,▁xxfld,▁xxrep,▁xxwrep,▁xxup,▁xxmaj --hard_vocab_limit=false
# ...

# %%
subword(200)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# '▁ J i an g ▁ X i an ▁ us es ▁the ▁ com p le x ▁b a ck s t or y ▁of ▁ L ing ▁ L ing ▁and ▁M a o ▁ D a o'

# %%
subword(10000)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# '▁J ian g ▁X ian ▁uses ▁the ▁complex ▁back story ▁of ▁L ing ▁L ing ▁and ▁Ma o ▁Da ob ing ▁to ▁study ▁Ma o \' s ▁" cul t ural ▁revolution " ▁( 1966 - 1 9 7 6'

# %% [markdown]
# ### Numericalization with fastai

# %%
toks = tkn(txt)
print(coll_repr(tkn(txt), 31))
# Out:
# (#158) ['xxbos','xxmaj','jiang','xxmaj','xian','uses','the','complex','backstory','of','xxmaj','ling','xxmaj','ling','and','xxmaj','mao','xxmaj','daobing','to','study','xxmaj','mao',"'s",'"','cultural','revolution','"','(','1966','-'...]

# %%
toks200 = txts[:200].map(tkn)
toks200[0]
# Out:
# (#158) ['xxbos','xxmaj','jiang','xxmaj','xian','uses','the','complex','backstory','of','xxmaj','ling','xxmaj','ling','and','xxmaj','mao','xxmaj','daobing','to'...]

# %%
num = Numericalize()
num.setup(toks200)
coll_repr(num.vocab,20)
# Out:
# "(#2152) ['xxunk','xxpad','xxbos','xxeos','xxfld','xxrep','xxwrep','xxup','xxmaj','the',',','.','and','a','of','to','is','in','it','i'...]"

# %%
nums = num(toks)[:20]; nums
# Out:
# TensorText([   2,    8,    0,    8,    0, 1269,    9, 1270,    0,   14,    8,    0,    8,    0,   12,    8,    0,    8,    0,   15])

# %%
' '.join(num.vocab[o] for o in nums)
# Out:
# 'xxbos xxmaj xxunk xxmaj xxunk uses the complex xxunk of xxmaj xxunk xxmaj xxunk and xxmaj xxunk xxmaj xxunk to'

# %% [markdown]
# ### Putting Our Texts into Batches for a Language Model

# %%
stream = "In this chapter, we will go back over the example of classifying movie reviews we studied in chapter 1 and dig deeper under the surface. First we will look at the processing steps necessary to convert text into numbers and how to customize it. By doing this, we'll have another example of the PreProcessor used in the data block API.\nThen we will study how we build a language model and train it for a while."
tokens = tkn(stream)
bs,seq_len = 6,15
d_tokens = np.array([tokens[i*seq_len:(i+1)*seq_len] for i in range(bs)])
df = pd.DataFrame(d_tokens)
display(HTML(df.to_html(index=False,header=None)))
# Out:
# <table border="1" class="dataframe">
#   <tbody>
#     <tr>
#       <td>xxbos</td>
#       <td>xxmaj</td>
#       <td>in</td>
#       <td>this</td>
#       <td>chapter</td>
#       <td>,</td>
#       <td>we</td>
#       <td>will</td>
#       <td>go</td>
#       <td>back</td>
#       <td>over</td>
#       <td>the</td>
#       <td>example</td>
#       <td>of</td>
#       <td>classifying</td>
#     </tr>
#     <tr>
#       <td>movie</td>
#       <td>reviews</td>
#       <td>we</td>
#       <td>studied</td>
#       <td>in</td>
#       <td>chapter</td>
#       <td>1</td>
#       <td>and</td>
#       <td>dig</td>
#       <td>deeper</td>
#       <td>under</td>
#       <td>the</td>
#       <td>surface</td>
#       <td>.</td>
#       <td>xxmaj</td>
#     </tr>
#     <tr>
#       <td>first</td>
#       <td>we</td>
#       <td>will</td>
#       <td>look</td>
#       <td>at</td>
#       <td>the</td>
#       <td>processing</td>
#       <td>steps</td>
#       <td>necessary</td>
# ...

# %%
bs,seq_len = 6,5
d_tokens = np.array([tokens[i*15:i*15+seq_len] for i in range(bs)])
df = pd.DataFrame(d_tokens)
display(HTML(df.to_html(index=False,header=None)))
# Out:
# <table border="1" class="dataframe">
#   <tbody>
#     <tr>
#       <td>xxbos</td>
#       <td>xxmaj</td>
#       <td>in</td>
#       <td>this</td>
#       <td>chapter</td>
#     </tr>
#     <tr>
#       <td>movie</td>
#       <td>reviews</td>
#       <td>we</td>
#       <td>studied</td>
#       <td>in</td>
#     </tr>
#     <tr>
#       <td>first</td>
#       <td>we</td>
#       <td>will</td>
#       <td>look</td>
#       <td>at</td>
#     </tr>
#     <tr>
#       <td>how</td>
#       <td>to</td>
#       <td>customize</td>
#       <td>it</td>
#       <td>.</td>
#     </tr>
#     <tr>
#       <td>of</td>
#       <td>the</td>
#       <td>preprocessor</td>
#       <td>used</td>
#       <td>in</td>
#     </tr>
#     <tr>
#       <td>will</td>
#       <td>study</td>
#       <td>how</td>
#       <td>we</td>
#       <td>build</td>
#     </tr>
#   </tbody>
# </table>

# %%
bs,seq_len = 6,5
d_tokens = np.array([tokens[i*15+seq_len:i*15+2*seq_len] for i in range(bs)])
df = pd.DataFrame(d_tokens)
display(HTML(df.to_html(index=False,header=None)))
# Out:
# <table border="1" class="dataframe">
#   <tbody>
#     <tr>
#       <td>,</td>
#       <td>we</td>
#       <td>will</td>
#       <td>go</td>
#       <td>back</td>
#     </tr>
#     <tr>
#       <td>chapter</td>
#       <td>1</td>
#       <td>and</td>
#       <td>dig</td>
#       <td>deeper</td>
#     </tr>
#     <tr>
#       <td>the</td>
#       <td>processing</td>
#       <td>steps</td>
#       <td>necessary</td>
#       <td>to</td>
#     </tr>
#     <tr>
#       <td>xxmaj</td>
#       <td>by</td>
#       <td>doing</td>
#       <td>this</td>
#       <td>,</td>
#     </tr>
#     <tr>
#       <td>the</td>
#       <td>data</td>
#       <td>block</td>
#       <td>xxup</td>
#       <td>api</td>
#     </tr>
#     <tr>
#       <td>a</td>
#       <td>language</td>
#       <td>model</td>
#       <td>and</td>
#       <td>train</td>
#     </tr>
#   </tbody>
# </table>

# %%
bs,seq_len = 6,5
d_tokens = np.array([tokens[i*15+10:i*15+15] for i in range(bs)])
df = pd.DataFrame(d_tokens)
display(HTML(df.to_html(index=False,header=None)))
# Out:
# <table border="1" class="dataframe">
#   <tbody>
#     <tr>
#       <td>over</td>
#       <td>the</td>
#       <td>example</td>
#       <td>of</td>
#       <td>classifying</td>
#     </tr>
#     <tr>
#       <td>under</td>
#       <td>the</td>
#       <td>surface</td>
#       <td>.</td>
#       <td>xxmaj</td>
#     </tr>
#     <tr>
#       <td>convert</td>
#       <td>text</td>
#       <td>into</td>
#       <td>numbers</td>
#       <td>and</td>
#     </tr>
#     <tr>
#       <td>we</td>
#       <td>'ll</td>
#       <td>have</td>
#       <td>another</td>
#       <td>example</td>
#     </tr>
#     <tr>
#       <td>.</td>
#       <td>\n</td>
#       <td>xxmaj</td>
#       <td>then</td>
#       <td>we</td>
#     </tr>
#     <tr>
#       <td>it</td>
#       <td>for</td>
#       <td>a</td>
#       <td>while</td>
#       <td>.</td>
#     </tr>
#   </tbody>
# </table>

# %%
nums200 = toks200.map(num)

# %%
dl = LMDataLoader(nums200)

# %%
x,y = first(dl)
x.shape,y.shape
# Out:
# (torch.Size([64, 72]), torch.Size([64, 72]))

# %%
' '.join(num.vocab[o] for o in x[0][:20])
# Out:
# 'xxbos xxmaj xxunk xxmaj xxunk uses the complex xxunk of xxmaj xxunk xxmaj xxunk and xxmaj xxunk xxmaj xxunk to'

# %%
' '.join(num.vocab[o] for o in y[0][:20])
# Out:
# 'xxmaj xxunk xxmaj xxunk uses the complex xxunk of xxmaj xxunk xxmaj xxunk and xxmaj xxunk xxmaj xxunk to study'

# %% [markdown]
# ## Training a Text Classifier

# %% [markdown]
# ### Language Model Using DataBlock

# %%
get_imdb = partial(get_text_files, folders=['train', 'test', 'unsup'])

dls_lm = DataBlock(
    blocks=TextBlock.from_folder(path, is_lm=True),
    get_items=get_imdb, splitter=RandomSplitter(0.1)
).dataloaders(path, path=path, bs=128, seq_len=80)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
dls_lm.show_batch(max_n=2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>text_</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>xxbos xxmaj if you want your vision of xxmaj chaplin limited to a lovable tramp and you get your belly laughs from pathos , watch something else . xxmaj if , however , you love slapstick comedy as performed by one of the best , do watch this one . \n\n xxmaj the image is of the tramp who really can not get the girl . xxmaj he spots another couple kissing on a park bench , and he has</td>
# ...

# %% [markdown]
# ### Fine-Tuning the Language Model

# %%
learn = language_model_learner(
    dls_lm, AWD_LSTM, drop_mult=0.3, 
    metrics=[accuracy, Perplexity()]).to_fp16()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='105070592' class='' max='105067061' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [105070592/105067061 00:02&lt;00:00]
#     </div>

# %%
learn.fit_one_cycle(1, 2e-2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.004471</td>
#       <td>3.901791</td>
#       <td>0.300509</td>
# ...

# %% [markdown]
# ### Saving and Loading Models

# %%
learn.save('1epoch')
# Out:
# Path('/root/.fastai/data/imdb/models/1epoch.pth')

# %%
#hide
learn = learn.load('1epoch')

# %%
learn.unfreeze()
learn.fit_one_cycle(1, 2e-3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>perplexity</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.686581</td>
#       <td>3.673901</td>
#       <td>0.327444</td>
# ...

# %%
learn.save_encoder('finetuned')

# %% [markdown]
# ### Text Generation

# %%
#hide
TEXT = "I liked this movie because"
N_WORDS = 40
N_SENTENCES = 2
preds = [learn.predict(TEXT, N_WORDS, temperature=0.75) 
         for _ in range(N_SENTENCES)]
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
# ...

# %%
print("\n".join(preds))
# Out:
# i liked this movie because it was n't scary or scary . The story was very well done and the special effects were pretty good . The plot was n't really what it was about . The script was really good but
# i liked this movie because i liked how James Stewart was given a good job by Stewart and Stewart . That i think is true . And there is a great scene in the movie where Stewart is

# %% [markdown]
# ### Creating the Classifier DataLoaders

# %%
dls_clas = DataBlock(
    blocks=(TextBlock.from_folder(path, vocab=dls_lm.vocab),CategoryBlock),
    get_y = parent_label,
    get_items=partial(get_text_files, folders=['train', 'test']),
    splitter=GrandparentSplitter(valid_name='test')
).dataloaders(path, path=path, bs=128, seq_len=72)

# %%
dls_clas.show_batch(max_n=3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %%
nums_samp = toks200[:10].map(num)

# %%
nums_samp.map(len)
# Out:
# (#10) [158,319,181,193,114,145,260,146,252,295]

# %%
learn = text_classifier_learner(dls_clas, AWD_LSTM, drop_mult=0.5, 
                                metrics=accuracy).to_fp16()

# %%
learn = learn.load_encoder('finetuned')

# %% [markdown]
# ### Fine-Tuning the Classifier

# %%
learn.fit_one_cycle(1, 2e-2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.287995</td>
#       <td>0.230371</td>
#       <td>0.907680</td>
#       <td>00:57</td>
# ...

# %%
learn.freeze_to(-2)
learn.fit_one_cycle(1, slice(1e-2/(2.6**4),1e-2))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.245147</td>
#       <td>0.191956</td>
#       <td>0.925920</td>
#       <td>01:03</td>
# ...

# %%
learn.freeze_to(-3)
learn.fit_one_cycle(1, slice(5e-3/(2.6**4),5e-3))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.206674</td>
#       <td>0.166853</td>
#       <td>0.937000</td>
#       <td>01:25</td>
# ...

# %%
learn.unfreeze()
learn.fit_one_cycle(2, slice(1e-3/(2.6**4),1e-3))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.165624</td>
#       <td>0.165039</td>
#       <td>0.937000</td>
#       <td>01:47</td>
# ...

# %% [markdown]
# ## Disinformation and Language Models

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ## Questionnaire

# %% [markdown]
# 1. What is "self-supervised learning"?
# 1. What is a "language model"?
# 1. Why is a language model considered self-supervised?
# 1. What are self-supervised models usually used for?
# 1. Why do we fine-tune language models?
# 1. What are the three steps to create a state-of-the-art text classifier?
# 1. How do the 50,000 unlabeled movie reviews help us create a better text classifier for the IMDb dataset?
# 1. What are the three steps to prepare your data for a language model?
# 1. What is "tokenization"? Why do we need it?
# 1. Name three different approaches to tokenization.
# 1. What is `xxbos`?
# 1. List four rules that fastai applies to text during tokenization.
# 1. Why are repeated characters replaced with a token showing the number of repetitions and the character that's repeated?
# 1. What is "numericalization"?
# 1. Why might there be words that are replaced with the "unknown word" token?
# 1. With a batch size of 64, the first row of the tensor representing the first batch contains the first 64 tokens for the dataset. What does the second row of that tensor contain? What does the first row of the second batch contain? (Careful—students often get this one wrong! Be sure to check your answer on the book's website.)
# 1. Why do we need padding for text classification? Why don't we need it for language modeling?
# 1. What does an embedding matrix for NLP contain? What is its shape?
# 1. What is "perplexity"?
# 1. Why do we have to pass the vocabulary of the language model to the classifier data block?
# 1. What is "gradual unfreezing"?
# 1. Why is text generation always likely to be ahead of automatic identification of machine-generated texts?

# %% [markdown]
# ### Further Research

# %% [markdown]
# 1. See what you can learn about language models and disinformation. What are the best language models today? Take a look at some of their outputs. Do you find them convincing? How could a bad actor best use such a model to create conflict and uncertainty?
# 1. Given the limitation that models are unlikely to be able to consistently recognize machine-generated texts, what other approaches may be needed to handle large-scale disinformation campaigns that leverage deep learning?

# %% [markdown]
# # My Project: fastai NLP Transfer Learning on AG News Dataset

# %% [markdown]
# Simple end-to-end NLP workflow using the fastai library and a small IMDb movie reviews dataset. It first trains a language model to understand English text by predicting the next word in movie reviews. Then, it transfers the learned language understanding to a classifier that predicts whether a review is positive or negative. The process uses transfer learning with an AWD-LSTM language model (a type of RNN).

# %%
from fastai.text.all import *
path = untar_data(URLs.IMDB_SAMPLE)

# Load the dataset into a DataFrame
df = pd.read_csv(path/'texts.csv')
df.head()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='573440' class='' max='571827' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.28% [573440/571827 00:00&lt;00:00]
#     </div>
#       label  \
# 0  negative
# 1  positive
# 2  negative
# 3  positive
# 4  negative
#
# ...

# %%
# Create DataLoaders for language model pretraining
dls_lm = TextDataLoaders.from_df(df, text_col='text', is_lm=True, valid_pct=0.1)

# Train a language model
learn_lm = language_model_learner(dls_lm, AWD_LSTM, drop_mult=0.3, metrics=[accuracy, Perplexity()])
learn_lm.fine_tune(1, 1e-2)

# Save encoder for transfer to classifier
learn_lm.save_encoder('imdb_enc')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
# ...

# %%
# Load classification DataLoaders
dls_clas = TextDataLoaders.from_df(df, text_col='text', label_col='label', valid_pct=0.1)

# Train a classifier using the LM encoder
learn_clas = text_classifier_learner(dls_clas, AWD_LSTM, drop_mult=0.5, metrics=accuracy)
learn_clas.load_encoder('imdb_enc')
learn_clas.fine_tune(1, 1e-2)

# Evaluate
learn_clas.show_results()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
# ...
